# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
from skimage import io as skio
from scipy.ndimage import uniform_filter

# %%
# Read image
g = skio.imread('alpenaster.jpg')/255
M,N,K=g.shape
print(g.shape)

# Here, the image to be filtered is the same as the guidance image
f = g.copy()

plt.close("all")
plt.figure(1, figsize=(7,7))
plt.imshow(g)
# Out:
# (800, 800, 3)

# %%
# epsilon
eps = 0.1

# filter radius
r = 5
ws = 2*r+1

# %%
# guided image filter
# ...

plt.figure(2, figsize=(7,7))
plt.imshow(u)

# %%
# details image
d = g-u

alpha = 4.0
e = u + alpha*d
e = np.clip(e, a_min=0, a_max=1)
plt.figure(3, figsize=(7,7))
plt.imshow(e)

skio.imsave("alpenaster_enhanced.png", np.uint8(e*255))
