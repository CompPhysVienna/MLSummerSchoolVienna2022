# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
from skimage import io as skio
from scipy.ndimage import uniform_filter

# %%
# Read guidance image
g = skio.imread('frauenschuh.png')/255
M,N=g.shape
print(g.shape)

# Image to be filtered is the same as the guidance image
f = g.copy()

plt.close("all")
plt.figure(1, figsize=(7,7))
plt.imshow(g, cmap="gray")
# Out:
# (768, 1024)

# %%
# epsilon
eps = 0.1

# filter radius
r = 5
ws = 2*r+1

# %%
# guided image filter

# ...

# visualize results
plt.figure(2, figsize=(7,7))
plt.imshow(u, cmap="gray")

# %%
# details image
d = f-u

# details enhancement
alpha = 4
e = u + alpha*d
e = np.clip(e, a_min=0, a_max=1)

plt.figure(3, figsize=(7,7))
plt.imshow(e, cmap="gray")

skio.imsave("frauenschuh_enhanced.png", np.uint8(e*255))
